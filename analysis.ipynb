# %%
import pandas as pd
from utils import Analysis

# %%
df = pd.read_parquet("search_sample_data.parquet")
columns = [
  'time', 'visitor_token', 'product_id', 'merchant_id', 'category_id', 
  'channel', 'query_text', 'device_type', 'sales_last_week',
  'sales_last_month', 'sales_last_year', 'previous_purchase',
  'free_shipping', 'is_sold_out', 'editor_pick', 'merchant_name',
  'product_name', 'price_in_cents', 'on_sale', 'category_name',
  'merchant_city', 'merchant_state', 'merchant_region', 'reviews',
  'add_to_cart', 'click', 'conversion'
]

df.columns = df.columns.str.lower()
df = df.reindex(columns, axis = 1)
do = Analysis(df)

# %%
do.explore()
# Out:
#                             Dtype  nunique  \
# time               datetime64[ns]    66063
# visitor_token              object    36139
# product_id                 object     9291
# merchant_id                object      851
# category_id                object      329
# channel                    object       16
# query_text                 object    15247
# device_type                object        8
# sales_last_week             int64       42
# sales_last_month            int64       59
# sales_last_year             int64      128
# previous_purchase            bool        2
# free_shipping                bool        2
# is_sold_out                  bool        2
# editor_pick                  bool        2
# merchant_name              object      851
# product_name               object     8954
# price_in_cents             object      423
# on_sale                      bool        2
# category_name              object      360
# merchant_city              object      325
# merchant_state             object       62
# merchant_region            object        6
# reviews                    object      118
# add_to_cart                  bool        2
# click                        bool        2
# conversion                   bool        2
#
#                                                               unique  nulls  \
# time               [2023-10-31 04:10:34.078000, 2023-10-25 09:17:...      0
# visitor_token      [7e11ebb5c86a22cf3d7fe5bc2e485ae9, 30d2001f93e...      0
# product_id         [920506213d5f99cff889a8d12a52758c, e6ac14a8f92...      0
# merchant_id        [5c918a3d791e7f42d91d1f175ddc5dd6, e229566db94...      0
# category_id        [693569f8fd124436589902200b2f0eb3, 77f72ea5ea6...      0
# channel            [Paid Search - Brand, Email - Marketing, Organ...      0
# query_text         [lobster roll, bourbon, gluten free desserts, ...      0
# device_type        [Mobile, Desktop, Tablet, Phablet, , TV, Porta...      0
# sales_last_week    [8, 2, 13, 14, 12, 7, 11, 10, 1, 4, 3, 5, 18, ...      0
# sales_last_month   [10, 2, 17, 18, 14, 12, 11, 13, 3, 8, 1, 9, 6,...      0
# sales_last_year    [29, 6, 42, 39, 26, 50, 27, 21, 13, 9, 10, 32,...      0
# previous_purchase                                      [False, True]      0
# free_shipping                                          [True, False]      0
# is_sold_out                                            [False, True]      0
# editor_pick                                            [False, True]      0
# merchant_name      [Luke's Lobster, Rebecca Ruth u00ae Bourbon Ba...      0
# product_name       [Lobster Roll Kit + Blueberry Pie (Frozen), Re...      0
# price_in_cents     [15995, 6595, 8995, 5995, 5495, 6995, 10995, 3...      0
# on_sale                                                [False, True]      0
# category_name      [Lobster Rolls, Chocolate, Doughnuts, Mini Pie...      0
# merchant_city      [Portland, Louisville, New York, Manhattan, Ne...      0
# merchant_state     [ME Maine, KY Kentucky, NY New York, LA Louisi...      0
# merchant_region       [northeast, south, southwest, west, midwest, ]      0
# reviews            [34, 18, 68, 62, 70, 43, 25, 113, 17, 0, 24, 4...      0
# add_to_cart                                            [False, True]      0
# click                                                  [False, True]      0
# conversion                                             [False, True]      0
#
#                    nulls%                               top    freq  \
# time                 0.00                                 -       -
# visitor_token        0.00  5e3d4b4e9fe3d0b2c141545df152d248      99
# product_id           0.00  f8cae79a13f055aef7f494d750c85fdf     438
# merchant_id          0.00  dc9b8b5db6bf249c30a04fa99be3de43    1623
# category_id          0.00  d332ed8693caa0ed046759d7f3983748    5552
# channel              0.00                            Direct   46000
# query_text           0.00              thanksgiving dinners    1721
# device_type          0.00                            Mobile   70360
# sales_last_week      0.00                                 -       -
# sales_last_month     0.00                                 -       -
# sales_last_year      0.00                                 -       -
# previous_purchase    0.00                             False  131206
# free_shipping        0.00                              True   97999
# is_sold_out          0.00                             False  129390
# editor_pick          0.00                             False  109839
# merchant_name        0.00                  Russ & Daughters    1623
# product_name         0.00                       Carrot Cake     495
# price_in_cents       0.00                              8995    9544
# on_sale              0.00                             False  130327
# category_name        0.00                         Meal Kits    5465
# merchant_city        0.00                          New York   23391
# merchant_state       0.00                       NY New York   36460
# merchant_region      0.00                         northeast   60486
# reviews              0.00                                 0   13039
# add_to_cart          0.00                             False  128913
# click                0.00                             False  110690
# conversion           0.00                             False  129934
#
#                                             mean                         min  \
# time               2023-10-30 02:42:08.604484864  2023-10-25 00:00:00.239000
# visitor_token                                  -                           -
# product_id                                     -                           -
# merchant_id                                    -                           -
# category_id                                    -                           -
# channel                                        -                           -
# query_text                                     -                           -
# device_type                                    -                           -
# sales_last_week                             7.36                        0.00
# sales_last_month                            9.70                        0.00
# sales_last_year                            22.39                        0.00
# previous_purchase                              -                           -
# free_shipping                                  -                           -
# is_sold_out                                    -                           -
# editor_pick                                    -                           -
# merchant_name                                  -                           -
# product_name                                   -                           -
# price_in_cents                                 -                           -
# on_sale                                        -                           -
# category_name                                  -                           -
# merchant_city                                  -                           -
# merchant_state                                 -                           -
# merchant_region                                -                           -
# reviews                                        -                           -
# add_to_cart                                    -                           -
# click                                          -                           -
# conversion                                     -                           -
#
#                                           25%                            50%  \
# time               2023-10-27 14:19:21.592000  2023-10-30 04:22:31.149499904
# visitor_token                               -                              -
# product_id                                  -                              -
# merchant_id                                 -                              -
# category_id                                 -                              -
# channel                                     -                              -
# query_text                                  -                              -
# device_type                                 -                              -
# sales_last_week                          4.00                           7.00
# sales_last_month                         6.00                           9.00
# sales_last_year                         11.00                          17.00
# previous_purchase                           -                              -
# free_shipping                               -                              -
# is_sold_out                                 -                              -
# editor_pick                                 -                              -
# merchant_name                               -                              -
# product_name                                -                              -
# price_in_cents                              -                              -
# on_sale                                     -                              -
# category_name                               -                              -
# merchant_city                               -                              -
# merchant_state                              -                              -
# merchant_region                             -                              -
# reviews                                     -                              -
# add_to_cart                                 -                              -
# click                                       -                              -
# conversion                                  -                              -
#
#                                              75%                         max  \
# time               2023-11-01 18:27:23.707000064  2023-11-03 23:59:57.489000
# visitor_token                                  -                           -
# product_id                                     -                           -
# merchant_id                                    -                           -
# category_id                                    -                           -
# channel                                        -                           -
# query_text                                     -                           -
# device_type                                    -                           -
# sales_last_week                            10.00                       41.00
# sales_last_month                           12.00                       58.00
# sales_last_year                            27.00                      131.00
# previous_purchase                              -                           -
# free_shipping                                  -                           -
# is_sold_out                                    -                           -
# editor_pick                                    -                           -
# merchant_name                                  -                           -
# product_name                                   -                           -
# price_in_cents                                 -                           -
# on_sale                                        -                           -
# category_name                                  -                           -
# merchant_city                                  -                           -
# merchant_state                                 -                           -
# merchant_region                                -                           -
# reviews                                        -                           -
# add_to_cart                                    -                           -
# click                                          -                           -
# conversion                                     -                           -
#
#                     std
# time                  -
# visitor_token         -
# product_id            -
# merchant_id           -
# category_id           -
# channel               -
# query_text            -
# device_type           -
# sales_last_week    4.13
# sales_last_month   5.83
# sales_last_year   17.95
# previous_purchase     -
# free_shipping         -
# is_sold_out           -
# editor_pick           -
# merchant_name         -
# product_name          -
# price_in_cents        -
# on_sale               -
# category_name         -
# merchant_city         -
# merchant_state        -
# merchant_region       -
# reviews               -
# add_to_cart           -
# click                 -
# conversion            -
